# %%
import pandas as pd
ind_hs_code = pd.read_csv("ind_hs_code.csv", encoding='cp949')
ind_hs_code
# Out:
#       KCPC2_CD            KCPC2_NM   CPC21_CD  \
# 0         1111               종자용 밀       1111
# 1         1111               종자용 밀       1111
# 2         1112                기타 밀       1112
# 3         1112                기타 밀       1112
# 4         1121             종자용 옥수수       1121
# ...        ...                 ...        ...
# 8514     97990              기타 서비스      97990
# 8515     97990              기타 서비스      97990
# 8516     98000              가사 서비스      98000
# 8517     99000  치외 법권적 조직 및 기관 서비스      99000
# 8518     99000  치외 법권적 조직 및 기관 서비스      99000
#
#                                             CPC21_EN_NM   ISIC4_CD  \
# 0                                           Wheat, seed      111.0
# 1                                           Wheat, seed      111.0
# 2                                          Wheat, other      111.0
# 3                                          Wheat, other      111.0
# 4                                    Maize (corn), seed      111.0
# ...
